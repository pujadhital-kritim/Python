# %% [markdown]
# ### Check whether a number is Prime or not

# %%
n = int(input("Enter a number: "))

if n <= 1:
    print("Not Prime")
else:
    for i in range(2, n):
        if n % i == 0:
            print("Not Prime")
            break
    else:
        print("Prime")
# Out:
# Enter a number: 3
# Prime

# %% [markdown]
# ### Factorial of a number

# %%
n = int(input("Enter a number: "))

fact = 1

for i in range(1, n + 1):
    fact = fact * i

print("Factorial is:", fact)
# Out:
# Enter a number: 2
# Factorial is: 2

# %% [markdown]
# ### Take list from user and:
# - Find largest element
# - Find smallest element

# %%
# taking list input
nums = list(map(int, input("Enter numbers separated by space: ").split()))

# assume first element
largest = nums[0]
smallest = nums[0]

# loop through list
for num in nums:
    if num > largest:
        largest = num
    if num < smallest:
        smallest = num

print("Largest:", largest)
print("Smallest:", smallest)
# Out:
# Enter numbers separated by space: 2 3 45 6
# Largest: 45
# Smallest: 2

# %% [markdown]
# ### Count how many even and odd numbers in list

# %%
numbers = list(map(int, input("Enter numbers: ").split()))

even = 0
odd = 0

for num in numbers:
    if num % 2 == 0:
        even += 1
    else:
        odd += 1

print("Even count:", even)
print("Odd count:", odd)
# Out:
# Enter numbers: 3 4 5 7 8
# Even count: 2
# Odd count: 3

# %% [markdown]
# ### Swap two numbers without using third variable

# %%
a =10
b=20

a,b=b,a
print(a)
print(b)
# Out:
# 20
# 10

# %% [markdown]
# ### Find second largest number in list

# %%
numbers = list(map(int, input("Enter numbers: ").split()))

largest = numbers[0]
secondLargest = numbers[0]

for num in numbers:
    if num > largest:
        secondLargest = largest
        largest = num
    elif num > secondLargest and num != largest:
        secondLargest = num

print("Largest:", largest)
print("Second Largest:", secondLargest)
# Out:
# Enter numbers: 2 3 45 6 78
# Largest: 78
# Second Largest: 45
